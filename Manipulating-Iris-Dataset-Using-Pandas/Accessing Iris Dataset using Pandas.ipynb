# %%
import pandas as pd
iris=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")
iris
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# 5    4.6  3.4  1.4  0.3     Iris-setosa
# 6    5.0  3.4  1.5  0.2     Iris-setosa
# 7    4.4  2.9  1.4  0.2     Iris-setosa
# 8    4.9  3.1  1.5  0.1     Iris-setosa
# 9    5.4  3.7  1.5  0.2     Iris-setosa
# 10   4.8  3.4  1.6  0.2     Iris-setosa
# 11   4.8  3.0  1.4  0.1     Iris-setosa
# 12   4.3  3.0  1.1  0.1     Iris-setosa
# 13   5.8  4.0  1.2  0.2     Iris-setosa
# 14   5.7  4.4  1.5  0.4     Iris-setosa
# 15   5.4  3.9  1.3  0.4     Iris-setosa
# 16   5.1  3.5  1.4  0.3     Iris-setosa
# 17   5.7  3.8  1.7  0.3     Iris-setosa
# 18   5.1  3.8  1.5  0.3     Iris-setosa
# 19   5.4  3.4  1.7  0.2     Iris-setosa
# 20   5.1  3.7  1.5  0.4     Iris-setosa
# 21   4.6  3.6  1.0  0.2     Iris-setosa
# ...

# %%
## Making copy of iris dataset
df=iris.copy()

# %%
##Type of iris and df objects
print(type(df))
print(type(iris))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
##head of the dataset, by-default 5
df.head(6)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa

# %%
##Number of Rows and Columns of Dataset
df.shape
# Out:
# (149, 5)

# %%
##Type of data in dataset
df.dtypes
# Out:
# 5.1            float64
# 3.5            float64
# 1.4            float64
# 0.2            float64
# Iris-setosa     object
# dtype: object

# %%
##Current Headers
df.columns
# Out:
# Index(['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], dtype='object')

# %%
##Changing column headers
df.columns=["sl","sw","pl","pw","Flower_Type"]
df.columns
# Out:
# Index(['sl', 'sw', 'pl', 'pw', 'Flower_Type'], dtype='object')

# %%
print(df.columns)
# Out:
# Index(['sl', 'sw', 'pl', 'pw', 'Flower_Type'], dtype='object')

# %%
##Describe data present in dataset, count is number of valid entries, for "NAN" count differs accordingly
df.describe()
# Out:
#                sl          sw          pl          pw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
##Accessing a particular column
print(df.pl) 
## can also be accessed using print(df["sl"])
# Out:
# 0      1.4
# 1      1.3
# 2      1.5
# 3      1.4
# 4      1.7
# 5      1.4
# 6      1.5
# 7      1.4
# 8      1.5
# 9      1.5
# 10     1.6
# 11     1.4
# 12     1.1
# 13     1.2
# 14     1.5
# 15     1.3
# 16     1.4
# 17     1.7
# 18     1.5
# 19     1.7
# 20     1.5
# 21     1.0
# 22     1.7
# 23     1.9
# 24     1.6
# 25     1.6
# 26     1.5
# 27     1.4
# 28     1.6
# 29     1.6
#       ...
# 119    5.7
# 120    4.9
# 121    6.7
# 122    4.9
# 123    5.7
# 124    6.0
# 125    4.8
# 126    4.9
# 127    5.6
# 128    5.8
# 129    6.1
# 130    6.4
# 131    5.6
# 132    5.1
# 133    5.6
# 134    6.1
# 135    5.6
# 136    5.5
# 137    4.8
# 138    5.4
# 139    5.6
# 140    5.1
# 141    5.1
# 142    5.9
# 143    5.7
# 144    5.2
# 145    5.0
# 146    5.2
# 147    5.4
# 148    5.1
# Name: pl, Length: 149, dtype: float64

# %%
##Null entries in dataset
df.isnull()
# Out:
#         sl     sw     pl     pw  Flower_Type
# 0    False  False  False  False        False
# 1    False  False  False  False        False
# 2    False  False  False  False        False
# 3    False  False  False  False        False
# 4    False  False  False  False        False
# 5    False  False  False  False        False
# 6    False  False  False  False        False
# 7    False  False  False  False        False
# 8    False  False  False  False        False
# 9    False  False  False  False        False
# 10   False  False  False  False        False
# 11   False  False  False  False        False
# 12   False  False  False  False        False
# 13   False  False  False  False        False
# 14   False  False  False  False        False
# 15   False  False  False  False        False
# 16   False  False  False  False        False
# 17   False  False  False  False        False
# 18   False  False  False  False        False
# 19   False  False  False  False        False
# ...

# %%
##Count of Null entries in each column
df.isnull().sum()
# Out:
# sl             0
# sw             0
# pl             0
# pw             0
# Flower_Type    0
# dtype: int64

# %%
##Accessing some particular data/slice of data from dataset
df.iloc[1:4,2:4]
##First slice is for rows and next slice is for columns
##Can't use directly like df[1:4,2:4]
# Out:
#     pl   pw
# 1  1.3  0.2
# 2  1.5  0.2
# 3  1.4  0.2
